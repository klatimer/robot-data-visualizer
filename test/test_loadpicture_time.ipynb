# %%
print('First you need to run staticmap_for_gps.py in tools directory to generate pictures then run this script.')
# Out:
# First you need to run staticmap_for_gps.py in tools directory to generate pictures then run this script.

# %%
import sys
sys.path.append('..')
import tools

# %%
# !ls
# Out:
# LICENSE          docs             requirements.txt tools
# README.md        environment.yml  setup.py
# data             gui              test

# %%
import os
os.chdir("data")
# !ls
# Out:
# 2013-01-10               2013-01-10_hokuyo.tar.gz 2013-01-10_sen.tar.gz

# %%
os.chdir('2013-01-10')

# %%
# !ls
# Out:
# README.txt             umich16.png            umich35.png
# gps.csv                umich17.png            umich36.png
# gps_rtk.csv            umich18.png            umich37.png
# gps_rtk_err.csv        umich19.png            umich38.png
# hokuyo_30m.bin         umich2.png             umich39.png
# hokuyo_4m.bin          umich20.png            umich4.png
# kvh.csv                umich21.png            umich40.png
# ms25.csv               umich22.png            umich41.png
# ms25_euler.csv         umich23.png            umich42.png
# odometry_cov.csv       umich24.png            umich43.png
# odometry_cov_100hz.csv umich25.png            umich44.png
# odometry_mu.csv        umich26.png            umich45.png
# odometry_mu_100hz.csv  umich27.png            umich46.png
# umich0.png             umich28.png            umich47.png
# umich1.png             umich29.png            umich5.png
# umich10.png            umich3.png             umich6.png
# ...

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 
import numpy as np
import datetime

start = datetime.datetime.now()
for i in range(48):
    pic = mpimg.imread('umich' + str(i) + '.png')
    plt.imshow(pic) 
    plt.axis('off') 
    plt.show()
end = datetime.datetime.now()

# %%
print (end-start)
# Out:
# 0:00:04.876807

# %%
print('The total time is 5 seconds which means we need 0.1s for load one picture which is acceptable.')
# Out:
# The total time is 5 seconds which means we need 0.1s for load one picture which is acceptable.
